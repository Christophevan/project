# %%
# %matplotlib inline

import numpy as np
import requests
from urlparse import parse_qsl
from pattern import web
import matplotlib.pyplot as plt
from bs4 import BeautifulSoup as bs 
from collections import defaultdict
import pandas as pd
from operator import itemgetter
from datetime import date as make_date
from itertools import permutations, combinations
from scipy.stats.stats import pearsonr
import networkx as nx

#Used in get player data
import urllib2
import mechanize

# %%
# Set some nicer defaults for matplotlib
from matplotlib import rcParams

#colorbrewer2 Dark2 qualitative color table
dark2_colors = [(0.10588235294117647, 0.6196078431372549, 0.4666666666666667),
                (0.8509803921568627, 0.37254901960784315, 0.00784313725490196),
                (0.4588235294117647, 0.4392156862745098, 0.7019607843137254),
                (0.9058823529411765, 0.1607843137254902, 0.5411764705882353),
                (0.4, 0.6509803921568628, 0.11764705882352941),
                (0.9019607843137255, 0.6705882352941176, 0.00784313725490196),
                (0.6509803921568628, 0.4627450980392157, 0.11372549019607843)]

rcParams['figure.figsize'] = (10, 6)
rcParams['figure.dpi'] = 200
rcParams['axes.color_cycle'] = dark2_colors
rcParams['lines.linewidth'] = 2
rcParams['axes.facecolor'] = 'white'
rcParams['font.size'] = 14
rcParams['patch.edgecolor'] = 'white'
rcParams['patch.facecolor'] = dark2_colors[0]
rcParams['font.family'] = 'StixGeneral'


def remove_border(axes=None, top=False, right=False, left=True, bottom=True):
    """
    Minimize chartjunk by stripping out unnecesasry plot borders and axis ticks
    
    The top/right/left/bottom keywords toggle whether the corresponding plot border is drawn
    """
    ax = axes or plt.gca()
    ax.spines['top'].set_visible(top)
    ax.spines['right'].set_visible(right)
    ax.spines['left'].set_visible(left)
    ax.spines['bottom'].set_visible(bottom)
    
    #turn off all ticks
    ax.yaxis.set_ticks_position('none')
    ax.xaxis.set_ticks_position('none')
    
    #now re-enable visibles
    if top:
        ax.xaxis.tick_top()
    if bottom:
        ax.xaxis.tick_bottom()
    if left:
        ax.yaxis.tick_left()
    if right:
        ax.yaxis.tick_right()
        
pd.set_option('display.width', 500)
pd.set_option('display.max_columns', 100)

# %% [markdown]
# ## Team Data Collection

# %% [markdown]
# Here we implement functions to scrape team data from the hoopdata site

# %%
"""
Function: get_team_names()
	Get the team names

Parameters:
	None
    
Returns:
	team_data: A list with the abreviated team name
"""
def get_team_names():
    url = 'http://www.hoopdata.com/teamff.aspx?yr=2012&type=pg'
    txt = requests.get(url).text

    #Import data to beautiful soup
    soup = bs(txt)
        
    #Get all tables and accumulate a list of sub_headers
    tables = soup.find_all('table', id='MyGridView')
    sub_headers = [header.a.string for header in tables[5].find_all('th')[1:]]
    
    #Get the relevant table and table rows
    tab = soup.find_all('table', id='MyGridView')[5]
    tabrow = tab.find_all('tr', onmouseover = "this.style.backgroundColor = '#FF8800';")
    
    #Iterate through each row, to get the team names
    
    teams = []
    for row in tabrow:
        #Get all columns in this row
        col = row.find_all('td')
            
        #Make a list of the team names
        teams.append(str(col[0].a.string))
        
    return teams

# %%
"""
Function: get_team_data()
	Get the team data

Parameters:
	None
    
Returns:
	team_data: A dict containing team data keyed on abbreviated team name
"""
def get_team_data():
    
    #Define category headers
    headers = ['overall','efg','ftr','tor','orr']
            
    #Get list of team names, years
    teams = get_team_names()
    years = range(2007, 2013)
    
    #Initialize the dict we will be returning
    team_data = defaultdict(dict)
    
    #Iteratate over years for which there is data available
    for year in years:
        #Get text from hoopdata page, concating year to be scraped
        url = 'http://www.hoopdata.com/teamff.aspx?yr=' + str(year) + '&type=pg'
        txt = requests.get(url).text

        #Import data to beautiful soup
        soup = bs(txt)
        
        #Get all tables and accumulate a list of sub_headers
        tables = soup.find_all('table', id='MyGridView')
        sub_headers = [header.a.string for header in tables[5].find_all('th')[1:]]
        
        #Get the relevant table and table rows
        tab = soup.find_all('table', id='MyGridView')[5]
        tabrow = tab.find_all('tr', onmouseover = "this.style.backgroundColor = '#FF8800';")
        
        #Iterate through each row, scraping the data
        for row in tabrow:
            temp_dict = defaultdict(dict)
            
            #Get all columns in this row
            col = row.find_all('td')
            
            #Store the team name
            team = str(col[0].a.string)
            
            #Iterate over the columns storing the data in the relevant category
            for i,val in enumerate(col[1:]):
                
                # Comments here follow the follow notation:
                # Category Header - Subheader1, Subheader2, Subheader3
                
                # Overall - OffEff, DefEff, Diff
                if i<=2:
                    temp_dict[headers[0]][sub_headers[i]] = val.string
                    
                # EFG% - Own, Opp, Diff
                elif i<=5:
                    temp_dict[headers[1]][sub_headers[i]] = val.string
                    
                # FTR - Own, Opp, Diff
                elif i<=8:
                    temp_dict[headers[2]][sub_headers[i]] = val.string
                
                # TOR - Own, Opp, Diff
                elif i<=11:
                    temp_dict[headers[3]][sub_headers[i]] = val.string
                # ORR - Own, Opp, Diff
                elif i<=14: 
                    temp_dict[headers[4]][sub_headers[i]] = val.string
                    
            #Account for franchise move
            if team == 'SEA':
                team = 'OKC'
            
            # Add the accumulated data to the finalized dict
            team_data[team][year] = temp_dict
    
    return team_data

# %% [markdown]
# ## Game Data Collection

# %% [markdown]
# These functions get the team's game scores results from throughout the season

# %%
"""
Function: get_abrv_name(unabrv_name)
	Get the abviation for a given name

Parameters:
	unabrv_name: The unabreviated name of a basketball team
    
Returns:
	abrv_name: A string of the abreviation for the team name
"""
def get_abrv_name(unabrv_name):
    abrvs = {'Atlanta Hawks'                     : 'ATL',
             'St. Louis Hawks'                   : 'ATL', #Franchise Relocation
             'Milwaukee Hawks'                   : 'ATL', #Franchise Relocation
             'Boston Celtics'                    : 'BOS',
             'Brooklyn Nets'                     : 'NJN',
             'New Jersey Nets'                   : 'NJN', #Franchise Relocation
             'New York Nets'                     : 'NJN', #Franchise Relocation
             'Charlotte Bobcats'                 : 'CHA',
             'Chicago Bulls'                     : 'CHI',
             'Cleveland Cavaliers'               : 'CLE',
             'Dallas Mavericks'                  : 'DAL',
             'Denver Nuggets'                    : 'DEN',
             'Detroit Pistons'                   : 'DET',
             'Golden State Warriors'             : 'GSW',
             'Philadelphia Warriors'             : 'GSW', #Franchise Relocation
             'San Francisco Warriors'            : 'GSW', #Franchise Relocation
             'Houston Rockets'                   : 'HOU',
             'San Diego Rockets'                 : 'HOU', #Franchise Relocation
             'Indiana Pacers'                    : 'IND',
             'Los Angeles Clippers'              : 'LAC',
             'Buffalo Braves'                    : 'LAC', #Franchise Relocation
             'San Diego Clippers'                : 'LAC', #Franchise Rename
             'Los Angeles Lakers'                : 'LAL',
             'Minneapolis Lakers'                : 'LAL', #Franchise Relocation
             'Memphis Grizzlies'                 : 'MEM',
             'Vancouver Grizzlies'               : 'MEM', #Franchise Relocation
             'Miami Heat'                        : 'MIA',
             'Milwaukee Bucks'                   : 'MIL',
             'Minnesota Timberwolves'            : 'MIN',
             'New Orleans Hornets'               : 'NOR',
             'New Orleans Pelicans'              : 'NOR', #Franchise Rename
             'New Orleans/Oklahoma City Hornets' : 'NOR', #Franchise Relocation
             'Charlotte Hornets'                 : 'NOR', #Franchise Relocation
             'New York Knicks'                   : 'NYK',
             'Oklahoma City Thunder'             : 'OKC', #Franchise Relocation
             'Seattle SuperSonics'               : 'OKC',
             'Orlando Magic'                     : 'ORL',
             'Philadelphia 76ers'                : 'PHI',
             'Syracuse Nationals'                : 'PHI', #Franchise Relocation
             'Phoenix Suns'                      : 'PHO',
             'Portland Trail Blazers'            : 'POR',
             'Sacramento Kings'                  : 'SAC',
             'Cincinnati Royals'                 : 'SAC', #Franchise Relocation
             'Rochester Royals'                  : 'SAC', #Franchise Relocation
             'Kansas City-Omaha Kings'           : 'SAC', #Franchise Relocation
             'Kansas City Kings'                 : 'SAC', #Franchise Relocation
             'San Antonio Spurs'                 : 'SAS', 
             'Toronto Raptors'                   : 'TOR',
             'Utah Jazz'                         : 'UTH',
             'New Orleans Jazz'                  : 'UTH', #Franchise Relocation
             'Washington Wizards'                : 'WAS',
             'Chicago Packers'                   : 'WAS', #Franchise Rename
             'Chicago Zephyrs'                   : 'WAS', #Franchise Rename              
             'Baltimore Bullets'                 : 'WAS', #Franchise Rename             
             'Capital Bullets'                   : 'WAS', #Franchise Rename
             'Washington Bullets'                : 'WAS'} #Franchise Rename

    
    #Return abreviated name
    return str(abrvs[unabrv_name])

# %%
"""
Function: get_game_data(year)
	Get the result of each game for a given year

Parameters:
	year: The year to scrape game results from
    
Returns:
	game_data: A dict containing a tuple of the date and final score of the game keyed on the teams playing. That is:
    {(team1, team2): (team1_score, team2_score)}
"""
def get_game_data(year):
    
    #Initialize the dict we will be returning
    game_data = defaultdict(list)
    
    #Get text from website, concating year to be scraped
    url = 'http://www.basketball-reference.com/leagues/NBA_' + str(year) + '_games.html#games::none'
    txt = requests.get(url).text

    #Import data to beautiful soup
    soup = bs(txt, 'html.parser') 
    
    #Get desired table and iterable of rows
    table = soup.find('table', id='games')
    rows = table.find_all('tr')[1:]
    
    #Iterate over the rows of the table, getting the name and scores
    for row in rows:
        #Find all data lines in each table row
        lines = row.find_all('td')

        #Get the date of each game by parsing the query url
        query_url = lines[0].a['href'].split('?')[1]
        date_parse = parse_qsl(query_url)
        get_date_info = itemgetter(1)
        
        # Get the date values, cast to integer, and create date in standard notation
        month, day, yr = map(get_date_info, date_parse)
        date = make_date(int(yr), int(month), int(day))
        
        #Get visitor information
        visit =  str(lines[2].text)
        vist_score = int(lines[3].text)
        
        #Get home team info
        home = str(lines[4].text)
        home_score = int(lines[5].text)
        
        #Convert full names to abreviated names for keying
        home_abrv = get_abrv_name(home)
        vist_abrv = get_abrv_name(visit)
        
        #Save the score data
        game_data[(home_abrv, vist_abrv)].append((date, home_score, vist_score))

    return game_data

# %% [markdown]
# ## Get League Standings

# %%
"""
Function: get_league_standings(year)
	Get the league standings for the year requested

Parameters:
	year: The year to collect standings from
    
Returns:
	game_data: A dict containing league wide standings keyed on the abreviated team name. Specifically:
    {abrv_team_name: league_standing}
"""
def get_league_standings(year):
    #Initialize the dict we will be returning
    league_standings = {}
    
    #Get text from website, concating year to be scraped
    url = 'http://www.basketball-reference.com/leagues/NBA_' + str(year) + '_standings.html'
    txt = requests.get(url).text

    #Import data to beautiful soup
    soup = bs(txt, 'html.parser') 
    
    #Get desired table and iterable of rows
    standings_table = soup.find('table', id='expanded-standings')
    rows = standings_table.tbody.find_all('tr')
    
    #Iterate over the rows of the table, getting the name and scores
    for rnk, row in enumerate(rows):
    
        #Get team name and convert to abreviated name
        unabrv_name = str(row.a.text)
        abrv_name = get_abrv_name(unabrv_name)
        
        #Calculate and save rank (adjust for 0-indexing)
        league_standings[abrv_name] = rnk + 1
        
    return league_standings

# %% [markdown]
# ## Player Data Collection

# %%
# This is a helper function to check if a string contains digits and is used to eliminate some strings captured that are not names 
def contains_digits(d):
    _digits = re.compile('\d')
    return bool(_digits.search(d))

#This function scrapes the player data page
def fplayerstat(soup4):
    for each in soup4.find_all('table')[2].find_all('tr')[1:]:

        #Finds name of the player. 
        if contains_digits(each.td.text):
            continue
        else:
            name = each.td.text
        
        #Adds first statistic playerdict since this is formatted differently. 
        #Using name and statistic name as keys. 
        try:
            playerdict[name][list_attr[1]] =  each.td.next_sibling.a.string
        except:
            pass 
        
        #Adds statistics to the dictionary. Using same keys as above. 
        counter = 2
        while True: 
            try: 
                playerdict[name][list_attr[counter]] = each.find_all('td')[counter].text
                counter = counter +1 
            except:
                break
                
    return playerdict 

#This traverses through the Javascript do_PostBack and returns the html of the page. 
def getpages(num):
    #Gets form
    br = mechanize.Browser()
    br.addheaders = [('User-agent', 'Mozilla/5.0 (X11; U; Linux i686; en-US; rv:1.9.0.1) Gecko/2008071615 Fedora/3.0.1-1.fc9 Firefox/3.0.1')]
    response = br.open("http://hoopdata.com/advancedstats.aspx")
    html = response.read()
    br.select_form(nr=0)
    
    #Sets form parameters
    br.set_all_readonly(False)           
    br["__EVENTTARGET"] = 'MyGridView'
    br["__EVENTARGUMENT"] = 'Page$' + str(num)
    
    for control in br.form.controls:           
       if control.type == "submit":
           control.disabled = True
    
    #Submits form parameters and gets page 
    response = br.submit()
    page = bs(response)
    
    return page

# %%
# Returns dict with player data
def get_playerdict():
    url="http://hoopdata.com/advancedstats.aspx"
    page=urllib2.urlopen(url)
    soup2 = bs(page.read())
    
    # This creates a list of the statistic names. This will later be used as keys. 
    list_attr = [] 
    for each in soup2.find_all('table')[2].find_all('tr',align = 'center')[0].find_all('th'):
        list_attr.append(each.get_text())
    
    playerdict = defaultdict(dict) 
    
    #Creating a dictionary for the first page. Later pages will be merged onto this. 
    playerdict = fplayerstat(soup2) 
    
    #This finds the number of pages there are. Creates list_page of the page numbers. 
    list_page = [] 
    for each in soup2.find_all('a',href=re.compile("javascript:__doPostBack\('MyGridView','Page")):
        list_page.append(int(each.text)) 
    
    #Creates num which is the page number of the last page. 
    num = max(list_page)
    
    #Creates list_pageinfo which is a list of the html of the pages. 
    list_pageinfo = [] 
    for i in range(2,num+1): 
        list_pageinfo.append(getpages(i))        
    
    #Scrapes each page with fplayerstat() and adds it onto our first dictionary, playerdict.    
    for each in list_pageinfo:
        temp = fplayerstat(each)
        playerdict.update(temp) 
        
    return playerdict

# %% [markdown]
# # Modeling

# %% [markdown]
# We begin our modeling with a very basic prediction engine. Below I create a preliminary model by examining the average score difference realized when a team ranked n plays a team ranked n+1 (rankings coming from the previous year). We look at data from 2007 forward.

# %%
#Define the years to be examined
years = range(2007, 2013)

#Initialize variables
standings = defaultdict(list)
game_data = defaultdict(list)
score_diff = defaultdict(list)

#Iterater over and save the historical data
for year in years:
    #Get game data for given year and the rankings data for the year prio
    standings[year] = get_league_standings(year-1) #Account for year notation difference
    game_data[year] = get_game_data(year)

    #Get the list of team names, create the list of permutations
    teams = standings[year].keys()
    perms = permutations(teams, 2)
    
    #Iterate over each matchup
    for matchup in perms:
        
        #Get the difference in rank between the home team and the visitors
        #This is calculated using ***(VISITOR - HOME)*** that means that if home is higher ranked then rnk_diff > 0
        rnk_diff = standings[year][matchup[1]] - standings[year][matchup[0]]
        
        #Iterate over the games they played and store the score difference (home - visitor)
        for game in game_data[year][matchup]:
            score_diff[rnk_diff].append(game[1] - game[2])

# %%
avg_diff = defaultdict(list)
diff_std = defaultdict(list)

#Calculate the average point difference and the std. deviation
for rnk_diff in score_diff.keys():
    #Only store data for rank diffences with enough observations to draw statisically significant observations
    req_obvs = pow((1.644853*np.std(score_diff[rnk_diff]))/np.mean(score_diff[rnk_diff]),2)
    num_obvs = len(score_diff[rnk_diff])
    if  num_obvs > req_obvs:
        avg_diff[rnk_diff] = np.mean(score_diff[rnk_diff])
        diff_std[rnk_diff] = np.std(score_diff[rnk_diff])

# %% [markdown]
# Having calculated the average and standard deviation of score difference, we move forward by first visualizing our findings and then applying them to the most recent

# %%
#Scatter average score difference
plt.scatter(avg_diff.keys(), avg_diff.values())

#Calcuate the best fit line and predict funciton
m, b = np.polyfit(avg_diff.keys(), avg_diff.values(), 1)
predict = lambda x: m*x+b

#plot best fitline
plt.plot(avg_diff.keys(), map(predict, avg_diff.keys()))

#Add plot labels and legend
plt.title('Observed Score Difference vs. Ranking Difference')
plt.ylabel('Score Difference')
plt.xlabel('Standing Difference (Visitor - Home)')
plt.legend(['Best Fit Line', 'Average Score Difference'], loc = 0)

remove_border()

# %% [markdown]
# We take a moment to interpret our findings. This linear model predicts that each ranking point (from the year prior) is associated with a 0.302 increase in score difference. This finding is inline with our hypothesis that teams ranked higher in year n-1 would outperform lower ranked teams in games played in year n. This model also provides some insight on the value of a home team advantage. In particular, the intercept value of 2.991 represents the predicted difference if a team were to play itself. Holding all other things equal, this value represents the benefit a team recieves from playing at home versus on the road.

# %% [markdown]
# The final step before going on to use this model to predict game outcomes is to develop a quantitative understanding of why this approach should provide meaningful insight. Below, we visualize how team standings change from year n to year n+1. Notably the correlation between rankings in one year to rankings the next year is strong (r = 0.6334) meaning that there is a some consistancy to rankings between years. However, the absolute rank change has a mean of 5.4667 and a standard deviation of 5.0049 this shows weakness in our assumption that rankings do not change from one year to the next. However, by virtue of change in rankings being zero-sum, our errors are normally distributed. We take these thoughts into account as we continue building our model.

# %%
#Looking at years during which noteams joined or left the league
years = range(2005, 2014)
#Initialize variables
standings = defaultdict(list)
rnk_prev = []
rnk_post = []
rnk_chng = []

#Iterate over and save the historical data
for year in years:
    #Get rankings data
    standings[year] = get_league_standings(year)

#Get team names
teams = standings[year].keys()
    
#Get the change in ranking from year to year
for year in years[1:]: 
    for team in teams:
        #store change in rank
        rnk_prev.append(standings[year-1][team])
        rnk_post.append(standings[year][team])
        rnk_chng.append(standings[year-1][team] - standings[year][team])

# %%
#Plot how teams change in rank from year to year
plt.scatter(rnk_prev, rnk_post)

#Print metrics
print 'Correlation Coefficient: ' + str(round(pearsonr(rnk_prev, rnk_post)[0],4))
print 'Average Absolute Change: ' + str(round(np.mean(np.abs(rnk_chng)),4))
print 'Std. Dev. of Absolute Rank Change: ' + str(round(np.std(np.abs(rnk_chng)),4))

#Add labels, title
plt.ylabel('Standing in Year n')
plt.xlabel('Standing in Year n-1')
plt.title('Change in League Standing Over 1 Year')
remove_border()


#Plot distribution of rank changes
plt.figure(2)

#Create histogram
plt.hist(rnk_chng, bins=25, normed= True)

#Add labels, title
plt.xlabel('Year over Year Rank Change')
plt.ylabel('Probability Density')
plt.title('Disitribution of Rank Changes')
remove_border()
# Out:
# Correlation Coefficient: 0.6334
# Average Absolute Change: 5.4667
# Std. Dev. of Absolute Rank Change: 5.0049

# %% [markdown]
# ## Predicting Outcomes (Part 1)

# %% [markdown]
# We now use our model to predict the outcome for the 2012-2013 season. Data from this season was not included in the creation of our model.

# %%
#Set the year to predict, get the game and ranking data
year = 2013
rankings= get_league_standings(year-1) #Account for year notation difference
games = get_game_data(year)

#Intialize variables
actual_score_diff = []
actual_outcome = []
pred_score_diff = []
pred_outcome = []
pred_err = []

#Iterate over the matchups and predict scores/outcomes
for matchup, game in games.items():
    #Get actual data
    rank_difference = rankings[matchup[1]] - rankings[matchup[0]]
    actual_score_diff.append(game[0][1] - game[0][2])
    actual_outcome.append(game[0][1] > game[0][2])
    
    #Make predicitons
    pred_score_diff.append(predict(rank_difference))
    pred_outcome.append(predict(rank_difference) > 0)
    
    #Calculate error
    pred_err.append(game[0][1] - game[0][2] - predict(rank_difference))

# %%
#We now take a moment to examine the accuracy of our results
correct = [pred == act for pred, act in zip(pred_outcome, actual_outcome)]
print 'Our first model is correct ' + str(round(100.*sum(correct)/len(correct),3)) + '% of the time'
# Out:
# Our first model is correct 65.172% of the time

# %%
###TO DO ERROR ANALYSIS####
###TO DO ERROR ANALYSIS####
###TO DO ERROR ANALYSIS####
###TO DO ERROR ANALYSIS####
###TO DO ERROR ANALYSIS####
###TO DO ERROR ANALYSIS####
###TO DO ERROR ANALYSIS####
#plt.scatter(pred_score_diff, pred_err)

# %% [markdown]
# ## Are you sure?

# %% [markdown]
# Having laid the foundation for our model we move forward by adding uncertainty to our predicitons.

# %%
win_diffs = [diff for diff in actual_score_diff if diff > 0]
lose_diffs = [diff for diff in actual_score_diff if diff < 0]
plot = plt.hist(win_diffs, bins = 15)
plot = plt.hist(lose_diffs, bins = 15)

np.mean(actual_score_diff)
np.std(actual_score_diff)
# Out:
# 12.981124390231669

# %% [markdown]
# ## The Game Network

# %%
year = 2013
games = get_game_data(year)

"""
Function
--------
game_graph

Parameters
----------
games : dict of lists
    The vote database returned from get_vote_data

Returns
-------
graph : NetworkX Graph object, with the following properties
    1. Each node in the graph is labeled by its abreviated team name
    2. The edges between two nodes are weighted by the number of 
       games the teames have played against each other
    3. Each edge also has a `difference` attribute, which measures the
       net score difference over all games played
"""
def get_game_graph(games):
    
    #Initialzie vars
    G = nx.DiGraph()
    teams = get_team_names()
    
    #Iterate over each matchup
    for matchup, game_data in games.items():
        
        #Check if swapped order edge already exists, if so just modify weigth and difference...
        if G.has_edge(matchup[1],matchup[0]):
            
            #Adjust the weight
            G[matchup[1]][matchup[0]]['weight'] += len(game_data)
            
            #Adjust the score diff
            for game in game_data:
                G[matchup[1]][matchup[0]]['difference'] += float(game[2] - game[1])
                
            #Scale the difference by # of games played
            G[matchup[1]][matchup[0]]['difference'] /= G[matchup[1]][matchup[0]]['weight']
            
            #Add the inverse edge
            G.add_edge(*matchup, weight= G[matchup[1]][matchup[0]]['weight'], difference= -G[matchup[1]][matchup[0]]['difference'])
       
        #...else create the edge with weight = 1, diff = score_diff
        else:
        
            G.add_edge(*matchup, weight=0, difference=0)
            
            #Take count of score_diff and weight
            for game in game_data:
                G[matchup[0]][matchup[1]]['difference'] += float(game[1] - game[2])
                G[matchup[0]][matchup[1]]['weight'] += 1.
                
            #Scale the difference by # of games played
            G[matchup[0]][matchup[1]]['difference'] /= G[matchup[0]][matchup[1]]['weight']
                
    #Create nodes for each team
    for team_name in get_team_names():
        G.add_node(team_name)
        
    return G

# %%
year = 2013
games = get_game_data(year)
game_graph = get_game_graph(games)

# %%
pg_rnk = nx.nx.pagerank_numpy(game_graph, weight = 'difference')

# %%
sorted(pg_rnk.iteritems(), key=itemgetter(1))
#sorted(st_2013.iteritems(), key=itemgetter(1))
# Out:
# [('SAS', -0.1169829656147878),
#  ('NYK', -0.09483551631276455),
#  ('LAC', -0.08861816301219622),
#  ('DEN', -0.05345690223082995),
#  ('MEM', -0.04755865768095354),
#  ('NOR', -0.03075217324824774),
#  ('CHI', -0.012660548136360552),
#  ('BOS', -0.008974898642104151),
#  ('ATL', 0.00043384869949039727),
#  ('SAC', 0.0010563537836005275),
#  ('MIA', 0.0025839405679315233),
#  ('MIL', 0.018185408695028733),
#  ('DET', 0.023538071252015912),
#  ('MIN', 0.02477779339641998),
#  ('HOU', 0.030538934515295782),
#  ('GSW', 0.038283178750469486),
#  ('LAL', 0.04224501848238361),
#  ('OKC', 0.045410210217023864),
#  ('PHI', 0.04700179136833901),
#  ('WAS', 0.05069643721479688),
#  ('CLE', 0.0695929220931953),
#  ('DAL', 0.0745148894757416),
#  ('NJN', 0.07751604738052559),
#  ('ORL', 0.07909186676434657),
#  ('POR', 0.09550652304067062),
#  ('PHO', 0.1118143892695028),
#  ('CHA', 0.12246927611265973),
#  ('UTH', 0.12255576118421076),
#  ('IND', 0.1585439532359052),
#  ('TOR', 0.2174832093786906)]

# %%
st_2013 = get_league_standings(2013)
# Out:
# [('MIA', 1),
#  ('OKC', 2),
#  ('SAS', 3),
#  ('DEN', 4),
#  ('LAC', 5),
#  ('MEM', 6),
#  ('NYK', 7),
#  ('NJN', 8),
#  ('IND', 9),
#  ('GSW', 10),
#  ('CHI', 11),
#  ('HOU', 12),
#  ('LAL', 13),
#  ('ATL', 14),
#  ('UTH', 15),
#  ('BOS', 16),
#  ('DAL', 17),
#  ('MIL', 18),
#  ('PHI', 19),
#  ('TOR', 20),
#  ('POR', 21),
#  ('MIN', 22),
#  ('DET', 23),
#  ('WAS', 24),
#  ('SAC', 25),
#  ('NOR', 26),
#  ('PHO', 27),
#  ('CLE', 28),
#  ('CHA', 29),
#  ('ORL', 30)]

# %%
game_graph.edges()
# Out:
# [('MIL', 'DET'),
#  ('MIL', 'PHO'),
#  ('MIL', 'MIA'),
#  ('MIL', 'DAL'),
#  ('MIL', 'CLE'),
#  ('MIL', 'ORL'),
#  ('MIL', 'BOS'),
#  ('MIL', 'POR'),
#  ('MIL', 'NJN'),
#  ('MIL', 'NYK'),
#  ('MIL', 'OKC'),
#  ('MIL', 'SAS'),
#  ('MIL', 'IND'),
#  ('MIL', 'WAS'),
#  ('MIL', 'ATL'),
#  ('MIL', 'NOR'),
#  ('GSW', 'CHA'),
#  ('GSW', 'PHI'),
#  ('GSW', 'PHO'),
#  ('GSW', 'MIL'),
#  ('GSW', 'MIN'),
#  ('GSW', 'TOR'),
#  ('GSW', 'CHI'),
#  ('GSW', 'UTH'),
#  ('GSW', 'POR'),
#  ('GSW', 'DET'),
#  ('GSW', 'NJN'),
#  ('GSW', 'ORL'),
#  ('GSW', 'HOU'),
#  ('GSW', 'DEN'),
#  ('GSW', 'OKC'),
#  ('GSW', 'WAS'),
#  ('GSW', 'NOR'),
#  ('MIN', 'LAL'),
#  ('MIN', 'PHO'),
#  ('MIN', 'MIL'),
#  ('MIN', 'MEM'),
#  ('MIN', 'CHI'),
#  ('MIN', 'ATL'),
#  ('MIN', 'NJN'),
#  ('MIN', 'LAC'),
#  ('MIN', 'TOR'),
#  ('MIN', 'ORL'),
#  ('MIN', 'WAS'),
#  ('MIN', 'UTH'),
#  ('MIA', 'SAC'),
#  ('MIA', 'GSW'),
#  ('MIA', 'MIN'),
#  ('MIA', 'TOR'),
#  ('MIA', 'CHI'),
#  ('MIA', 'ATL'),
#  ('MIA', 'DET'),
#  ('MIA', 'NJN'),
#  ('MIA', 'LAC'),
#  ('MIA', 'DAL'),
#  ('MIA', 'ORL'),
#  ('MIA', 'DEN'),
#  ('MIA', 'SAS'),
#  ('MIA', 'WAS'),
#  ('MIA', 'NOR'),
#  ('ATL', 'LAL'),
#  ('ATL', 'GSW'),
#  ('ATL', 'SAC'),
#  ('ATL', 'CLE'),
#  ('ATL', 'BOS'),
#  ('ATL', 'DET'),
#  ('ATL', 'ORL'),
#  ('ATL', 'LAC'),
#  ('ATL', 'IND'),
#  ('ATL', 'OKC'),
#  ('ATL', 'SAS'),
#  ('ATL', 'MEM'),
#  ('ATL', 'NOR'),
#  ('BOS', 'PHI'),
#  ('BOS', 'PHO'),
#  ('BOS', 'GSW'),
#  ('BOS', 'SAC'),
#  ('BOS', 'MIA'),
#  ('BOS', 'CHI'),
#  ('BOS', 'MIN'),
#  ('BOS', 'NJN'),
#  ('BOS', 'LAC'),
#  ('BOS', 'NYK'),
#  ('BOS', 'DAL'),
#  ('BOS', 'DEN'),
#  ('BOS', 'SAS'),
#  ('BOS', 'WAS'),
#  ('BOS', 'IND'),
#  ('BOS', 'HOU'),
#  ('DET', 'PHI'),
#  ('DET', 'MIN'),
#  ('DET', 'DAL'),
#  ('DET', 'CLE'),
#  ('DET', 'UTH'),
#  ('DET', 'BOS'),
#  ('DET', 'NJN'),
#  ('DET', 'LAC'),
#  ('DET', 'NYK'),
#  ('DET', 'HOU'),
#  ('DET', 'CHI'),
#  ('DET', 'SAS'),
#  ('DET', 'MEM'),
#  ('DET', 'SAC'),
#  ('NYK', 'LAL'),
#  ('NYK', 'CHA'),
#  ('NYK', 'PHO'),
#  ('NYK', 'GSW'),
#  ('NYK', 'MIN'),
#  ('NYK', 'MIA'),
#  ('NYK', 'CHI'),
#  ('NYK', 'ATL'),
#  ('NYK', 'POR'),
#  ('NYK', 'ORL'),
#  ('NYK', 'LAC'),
#  ('NYK', 'TOR'),
#  ('NYK', 'OKC'),
#  ('NYK', 'HOU'),
#  ('NYK', 'NJN'),
#  ('NYK', 'SAS'),
#  ('NYK', 'WAS'),
#  ('NYK', 'NOR'),
#  ('DEN', 'LAL'),
#  ('DEN', 'NYK'),
#  ('DEN', 'MIL'),
#  ('DEN', 'MIN'),
#  ('DEN', 'DAL'),
#  ('DEN', 'CHI'),
#  ('DEN', 'ATL'),
#  ('DEN', 'DET'),
#  ('DEN', 'NJN'),
#  ('DEN', 'LAC'),
#  ('DEN', 'SAC'),
#  ('DEN', 'HOU'),
#  ('DEN', 'SAS'),
#  ('DEN', 'MEM'),
#  ('DEN', 'WAS'),
#  ('DAL', 'PHI'),
#  ('DAL', 'GSW'),
#  ('DAL', 'MIN'),
#  ('DAL', 'MEM'),
#  ('DAL', 'CHI'),
#  ('DAL', 'ATL'),
#  ('DAL', 'OKC'),
#  ('DAL', 'NYK'),
#  ('DAL', 'ORL'),
#  ('DAL', 'HOU'),
#  ('DAL', 'CLE'),
#  ('DAL', 'SAS'),
#  ('DAL', 'SAC'),
#  ('DAL', 'UTH'),
#  ('DAL', 'NOR'),
#  ('OKC', 'LAL'),
#  ('OKC', 'CHA'),
#  ('OKC', 'PHO'),
#  ('OKC', 'MIN'),
#  ('OKC', 'MIA'),
#  ('OKC', 'CLE'),
#  ('OKC', 'BOS'),
#  ('OKC', 'DET'),
#  ('OKC', 'NJN'),
#  ('OKC', 'LAC'),
#  ('OKC', 'SAC'),
#  ('OKC', 'DEN'),
#  ('OKC', 'CHI'),
#  ('OKC', 'SAS'),
#  ('OKC', 'MEM'),
#  ('OKC', 'WAS'),
#  ('OKC', 'NOR'),
#  ('POR', 'LAL'),
#  ('POR', 'CHA'),
#  ('POR', 'MIN'),
#  ('POR', 'MIA'),
#  ('POR', 'OKC'),
#  ('POR', 'ATL'),
#  ('POR', 'BOS'),
#  ('POR', 'DET'),
#  ('POR', 'NJN'),
#  ('POR', 'IND'),
#  ('POR', 'ORL'),
#  ('POR', 'HOU'),
#  ('POR', 'DEN'),
#  ('POR', 'SAS'),
#  ('POR', 'WAS'),
#  ('POR', 'NOR'),
#  ('POR', 'DAL'),
#  ('NJN', 'LAL'),
#  ('NJN', 'PHI'),
#  ('NJN', 'PHO'),
#  ('NJN', 'TOR'),
#  ('NJN', 'UTH'),
#  ('NJN', 'DAL'),
#  ('NJN', 'ORL'),
#  ('NJN', 'HOU'),
#  ('NJN', 'IND'),
#  ('NJN', 'MEM'),
#  ('NJN', 'WAS'),
#  ('NJN', 'ATL'),
#  ('NJN', 'NOR'),
#  ('TOR', 'CHA'),
#  ('TOR', 'PHO'),
#  ('TOR', 'MIL'),
#  ('TOR', 'MEM'),
#  ('TOR', 'DET'),
#  ('TOR', 'ATL'),
#  ('TOR', 'BOS'),
#  ('TOR', 'POR'),
#  ('TOR', 'ORL'),
#  ('TOR', 'SAC'),
#  ('TOR', 'OKC'),
#  ('TOR', 'DAL'),
#  ('TOR', 'DEN'),
#  ('TOR', 'SAS'),
#  ('TOR', 'WAS'),
#  ('TOR', 'NOR'),
#  ('CHI', 'LAL'),
#  ('CHI', 'PHI'),
#  ('CHI', 'MIL'),
#  ('CHI', 'SAC'),
#  ('CHI', 'CLE'),
#  ('CHI', 'ATL'),
#  ('CHI', 'POR'),
#  ('CHI', 'NJN'),
#  ('CHI', 'LAC'),
#  ('CHI', 'TOR'),
#  ('CHI', 'SAS'),
#  ('CHI', 'WAS'),
#  ('CHI', 'NOR'),
#  ('SAS', 'LAL'),
#  ('SAS', 'PHI'),
#  ('SAS', 'PHO'),
#  ('SAS', 'GSW'),
#  ('SAS', 'MIN'),
#  ('SAS', 'SAC'),
#  ('SAS', 'CLE'),
#  ('SAS', 'UTH'),
#  ('SAS', 'NJN'),
#  ('SAS', 'LAC'),
#  ('SAS', 'ORL'),
#  ('SAS', 'HOU'),
#  ('SAS', 'NOR'),
#  ('CHA', 'PHO'),
#  ('CHA', 'MIL'),
#  ('CHA', 'MIA'),
#  ('CHA', 'MIN'),
#  ('CHA', 'MEM'),
#  ('CHA', 'CHI'),
#  ('CHA', 'UTH'),
#  ('CHA', 'BOS'),
#  ('CHA', 'DET'),
#  ('CHA', 'NJN'),
#  ('CHA', 'DAL'),
#  ('CHA', 'HOU'),
#  ('CHA', 'ATL'),
#  ('CHA', 'DEN'),
#  ('CHA', 'SAS'),
#  ('CHA', 'SAC'),
#  ('CHA', 'IND'),
#  ('CHA', 'NOR'),
#  ('CLE', 'CHA'),
#  ('CLE', 'PHI'),
#  ('CLE', 'NYK'),
#  ('CLE', 'GSW'),
#  ('CLE', 'MIN'),
#  ('CLE', 'MIA'),
#  ('CLE', 'UTH'),
#  ('CLE', 'BOS'),
#  ('CLE', 'POR'),
#  ('CLE', 'NJN'),
#  ('CLE', 'LAC'),
#  ('CLE', 'TOR'),
#  ('CLE', 'DEN'),
#  ('CLE', 'MEM'),
#  ('CLE', 'WAS'),
#  ('CLE', 'NOR'),
#  ('UTH', 'LAL'),
#  ('UTH', 'PHO'),
#  ('UTH', 'MIL'),
#  ('UTH', 'MIA'),
#  ('UTH', 'TOR'),
#  ('UTH', 'CHI'),
#  ('UTH', 'ATL'),
#  ('UTH', 'BOS'),
#  ('UTH', 'POR'),
#  ('UTH', 'ORL'),
#  ('UTH', 'LAC'),
#  ('UTH', 'NYK'),
#  ('UTH', 'OKC'),
#  ('UTH', 'HOU'),
#  ('UTH', 'DEN'),
#  ('HOU', 'PHI'),
#  ('HOU', 'MIL'),
#  ('HOU', 'MIA'),
#  ('HOU', 'MIN'),
#  ('HOU', 'TOR'),
#  ('HOU', 'CLE'),
#  ('HOU', 'ATL'),
#  ('HOU', 'ORL'),
#  ('HOU', 'LAC'),
#  ('HOU', 'MEM'),
#  ('HOU', 'OKC'),
#  ('HOU', 'CHI'),
#  ('HOU', 'IND'),
#  ('HOU', 'WAS'),
#  ('HOU', 'NOR'),
#  ('WAS', 'LAL'),
#  ('WAS', 'CHA'),
#  ('WAS', 'PHI'),
#  ('WAS', 'SAC'),
#  ('WAS', 'MEM'),
#  ('WAS', 'ATL'),
#  ('WAS', 'DET'),
#  ('WAS', 'LAC'),
#  ('WAS', 'DAL'),
#  ('WAS', 'SAS'),
#  ('WAS', 'UTH'),
#  ('WAS', 'NOR'),
#  ('LAL', 'CHA'),
#  ('LAL', 'PHI'),
#  ('LAL', 'MIL'),
#  ('LAL', 'GSW'),
#  ('LAL', 'DAL'),
#  ('LAL', 'CLE'),
#  ('LAL', 'BOS'),
#  ('LAL', 'DET'),
#  ('LAL', 'MIA'),
#  ('LAL', 'LAC'),
#  ('LAL', 'SAC'),
#  ('LAL', 'ORL'),
#  ('LAL', 'HOU'),
#  ('LAL', 'TOR'),
#  ('LAL', 'NOR'),
#  ('PHI', 'CHA'),
#  ('PHI', 'TOR'),
#  ('PHI', 'PHO'),
#  ('PHI', 'MIL'),
#  ('PHI', 'MIA'),
#  ('PHI', 'MIN'),
#  ('PHI', 'SAC'),
#  ('PHI', 'UTH'),
#  ('PHI', 'POR'),
#  ('PHI', 'LAC'),
#  ('PHI', 'NYK'),
#  ('PHI', 'OKC'),
#  ('PHI', 'DEN'),
#  ('PHI', 'IND'),
#  ('PHI', 'MEM'),
#  ('PHI', 'ATL'),
#  ('PHI', 'NOR'),
#  ('PHO', 'LAL'),
#  ('PHO', 'MIA'),
#  ('PHO', 'CLE'),
#  ('PHO', 'ATL'),
#  ('PHO', 'POR'),
#  ('PHO', 'DET'),
#  ('PHO', 'LAC'),
#  ('PHO', 'DAL'),
#  ('PHO', 'ORL'),
#  ('PHO', 'HOU'),
#  ('PHO', 'DEN'),
#  ('PHO', 'CHI'),
#  ('PHO', 'MEM'),
#  ('PHO', 'WAS'),
#  ('MEM', 'LAL'),
#  ('MEM', 'MIL'),
#  ('MEM', 'GSW'),
#  ('MEM', 'SAC'),
#  ('MEM', 'MIA'),
#  ('MEM', 'CHI'),
#  ('MEM', 'UTH'),
#  ('MEM', 'BOS'),
#  ('MEM', 'POR'),
#  ('MEM', 'NYK'),
#  ('MEM', 'ORL'),
#  ('MEM', 'SAS'),
#  ('MEM', 'IND'),
#  ('LAC', 'CHA'),
#  ('LAC', 'TOR'),
#  ('LAC', 'MIL'),
#  ('LAC', 'GSW'),
#  ('LAC', 'SAC'),
#  ('LAC', 'DAL'),
#  ('LAC', 'POR'),
#  ('LAC', 'NJN'),
#  ('LAC', 'MEM'),
#  ('LAC', 'NOR'),
#  ('SAC', 'PHO'),
#  ('SAC', 'MIL'),
#  ('SAC', 'GSW'),
#  ('SAC', 'MIN'),
#  ('SAC', 'CLE'),
#  ('SAC', 'UTH'),
#  ('SAC', 'POR'),
#  ('SAC', 'NJN'),
#  ('SAC', 'NYK'),
#  ('SAC', 'HOU'),
#  ('SAC', 'NOR'),
#  ('ORL', 'CHA'),
#  ('ORL', 'PHI'),
#  ('ORL', 'SAC'),
#  ('ORL', 'CHI'),
#  ('ORL', 'BOS'),
#  ('ORL', 'DET'),
#  ('ORL', 'LAC'),
#  ('ORL', 'OKC'),
#  ('ORL', 'DEN'),
#  ('ORL', 'CLE'),
#  ('ORL', 'IND'),
#  ('ORL', 'WAS'),
#  ('ORL', 'NOR'),
#  ('IND', 'LAL'),
#  ('IND', 'TOR'),
#  ('IND', 'PHO'),
#  ('IND', 'GSW'),
#  ('IND', 'MIN'),
#  ('IND', 'SAC'),
#  ('IND', 'CHI'),
#  ('IND', 'UTH'),
#  ('IND', 'MIA'),
#  ('IND', 'DET'),
#  ('IND', 'LAC'),
#  ('IND', 'NYK'),
#  ('IND', 'OKC'),
#  ('IND', 'DAL'),
#  ('IND', 'DEN'),
#  ('IND', 'CLE'),
#  ('IND', 'SAS'),
#  ('IND', 'WAS'),
#  ('IND', 'NOR'),
#  ('NOR', 'PHO'),
#  ('NOR', 'MIN'),
#  ('NOR', 'MEM'),
#  ('NOR', 'UTH'),
#  ('NOR', 'BOS'),
#  ('NOR', 'DET'),
#  ('NOR', 'DEN')]
